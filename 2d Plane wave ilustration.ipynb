# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
_lambda = 3

# %%
def mk_wave_angle(theta, _lambda):
    x = np.linspace(0, 10, 1000)
    xx, yy = np.meshgrid(x, x)
    
    k = np.array([np.cos(theta), np.sin(theta)]) * 2*np.pi/(_lambda)
    z = np.sin(k[0] * xx + k[1]*yy)
    return z, x

# %%
z, x = mk_wave_angle(0, _lambda)
plt.imshow(z)

# %%
z, x = mk_wave_angle(np.deg2rad(45), _lambda)
plt.imshow(z)

# %%
z, x = mk_wave_angle(np.deg2rad(90), _lambda)
plt.imshow(z)
